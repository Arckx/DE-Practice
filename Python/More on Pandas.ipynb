# %%
import pandas as pd
df = pd.read_csv("ramen-ratings.csv")
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#To select the first row of data in a DataFrame
df.iloc[0]
# Out:
# Review #                         2580
# Brand                       New Touch
# Variety     T's Restaurant Tantanmen
# Style                             Cup
# Country                         Japan
# Stars                            3.75
# Top Ten                           NaN
# Name: 0, dtype: object

# %%
#To get a column with iloc
df.iloc[:, 1]
# Out:
# 0            New Touch
# 1             Just Way
# 2               Nissin
# 3              Wei Lih
# 4       Ching's Secret
#              ...
# 2575             Vifon
# 2576           Wai Wai
# 2577           Wai Wai
# 2578           Wai Wai
# 2579          Westbrae
# Name: Brand, Length: 2580, dtype: str

# %%
#To select just the second and third entries
df.iloc[1:3, 0]
# Out:
# 1    2579
# 2    2578
# Name: Review #, dtype: int64

# %%
#Label-based selection
df.loc[0, 'Country']
# Out:
# 'Japan'

# %%
df.loc[:, ['Style', 'Country', 'Stars']]
# Out:
#      Style   Country Stars
# 0      Cup     Japan  3.75
# 1     Pack    Taiwan     1
# 2      Cup       USA  2.25
# 3     Pack    Taiwan  2.75
# 4     Pack     India  3.75
# ...    ...       ...   ...
# 2575  Bowl   Vietnam   3.5
# 2576  Pack  Thailand     1
# 2577  Pack  Thailand     2
# 2578  Pack  Thailand     2
# 2579  Pack       USA   0.5
#
# [2580 rows x 3 columns]

# %%
#Manipulating the Index
df.set_index('Style')
# Out:
#        Review #           Brand  \
# Style
# Cup        2580       New Touch
# Pack       2579        Just Way
# Cup        2578          Nissin
# Pack       2577         Wei Lih
# Pack       2576  Ching's Secret
# ...         ...             ...
# Bowl          5           Vifon
# Pack          4         Wai Wai
# Pack          3         Wai Wai
# Pack          2         Wai Wai
# Pack          1        Westbrae
#
#                                                  Variety   Country Stars  \
# Style
# Cup                            T's Restaurant Tantanmen      Japan  3.75
# Pack   Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...    Taiwan     1
# Cup                        Cup Noodles Chicken Vegetable       USA  2.25
# Pack                       GGE Ramen Snack Tomato Flavor    Taiwan  2.75
# Pack                                     Singapore Curry     India  3.75
# ...                                                  ...       ...   ...
# Bowl   Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...   Vietnam   3.5
# Pack                      Oriental Style Instant Noodles  Thailand     1
# Pack                                      Tom Yum Shrimp  Thailand     2
# Pack                                Tom Yum Chili Flavor  Thailand     2
# Pack                                          Miso Ramen       USA   0.5
#
#       Top Ten
# Style
# Cup       NaN
# Pack      NaN
# Cup       NaN
# Pack      NaN
# Pack      NaN
# ...       ...
# Bowl      NaN
# Pack      NaN
# Pack      NaN
# Pack      NaN
# Pack      NaN
#
# [2580 rows x 6 columns]

# %%
df.describe()
# Out:
#           Review #
# count  2580.000000
# mean   1290.500000
# std     744.926171
# min       1.000000
# 25%     645.750000
# 50%    1290.500000
# 75%    1935.250000
# max    2580.000000

# %%
df.Country == 'Japan'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2575    False
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: Country, Length: 2580, dtype: bool

# %%
df.loc[df.Country == 'Japan']
# Out:
#       Review #            Brand                                      Variety  \
# 0         2580        New Touch                    T's Restaurant Tantanmen
# 6         2574          Acecook          Spice Deli Tantan Men With Cilantro
# 7         2573      Ikeda Shoku                        Nabeyaki Kitsune Udon
# 8         2572       Ripe'n'Dry                     Hokkaido Soy Sauce Ramen
# 13        2567           Nissin                 Deka Buto Kimchi Pork Flavor
# ...        ...              ...                                          ...
# 2554        26           Nissin        Soba Noodles With Mayo Mustard Squirt
# 2555        25           Nissin                     Demae Ramen Spicy Flavor
# 2556        24           Nissin  Demae Ramen Spicy Seafood With Chili Pepper
# 2567        13  Sapporo Ichiban                                    Chow Mein
# 2568        12  Sapporo Ichiban                                Shrimp Flavor
#
#      Style Country Stars  Top Ten
# 0      Cup   Japan  3.75      NaN
# 6      Cup   Japan     4      NaN
# 7     Tray   Japan  3.75      NaN
# 8     Pack   Japan  0.25      NaN
# 13    Bowl   Japan   4.5      NaN
# ...    ...     ...   ...      ...
# 2554  Pack   Japan     4      NaN
# 2555  Pack   Japan     3      NaN
# 2556  Pack   Japan     2      NaN
# 2567  Pack   Japan     5  2012 #4
# 2568  Pack   Japan   2.5      NaN
#
# [352 rows x 7 columns]

# %%
df.loc[df.Country.isin(['Japan', 'USA'])]
# Out:
#       Review #            Brand                              Variety Style  \
# 0         2580        New Touch            T's Restaurant Tantanmen    Cup
# 2         2578           Nissin        Cup Noodles Chicken Vegetable   Cup
# 6         2574          Acecook  Spice Deli Tantan Men With Cilantro   Cup
# 7         2573      Ikeda Shoku                Nabeyaki Kitsune Udon  Tray
# 8         2572       Ripe'n'Dry             Hokkaido Soy Sauce Ramen  Pack
# ...        ...              ...                                  ...   ...
# 2557        23           Nissin             Top Ramen Creamy Chicken  Pack
# 2567        13  Sapporo Ichiban                            Chow Mein  Pack
# 2568        12  Sapporo Ichiban                        Shrimp Flavor  Pack
# 2570        10            Smack                       Vegetable Beef  Pack
# 2579         1         Westbrae                           Miso Ramen  Pack
#
#      Country Stars  Top Ten
# 0      Japan  3.75      NaN
# 2        USA  2.25      NaN
# 6      Japan     4      NaN
# 7      Japan  3.75      NaN
# 8      Japan  0.25      NaN
# ...      ...   ...      ...
# 2557     USA   4.5      NaN
# 2567   Japan     5  2012 #4
# 2568   Japan   2.5      NaN
# 2570     USA   1.5      NaN
# 2579     USA   0.5      NaN
#
# [675 rows x 7 columns]

# %%
df.loc[df.Stars.notnull()]
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam   3.5
# 2576                     Oriental Style Instant Noodles  Pack  Thailand     1
# 2577                                     Tom Yum Shrimp  Pack  Thailand     2
# 2578                               Tom Yum Chili Flavor  Pack  Thailand     2
# 2579                                         Miso Ramen  Pack       USA   0.5
#
#      Top Ten
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2575     NaN
# 2576     NaN
# 2577     NaN
# 2578     NaN
# 2579     NaN
#
# [2580 rows x 7 columns]
